# %% [markdown]
# <a href="https://colab.research.google.com/github/Manishaarpara/Manishaarpara/blob/main/IDS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  print("hello world")
# Out:
# hello world

# %%
print("Testing segment 2")
# Out:
# Testing segment 2

# %%
#NUMBER 

var_1=4
var_2=4.8
var_3=4+2j #bilangan komplek dengan angka imajiner(j)
print(var_1)
print(type(var_1))

print(var_2)
print(type(var_2))

print(var_3)
print(type(var_3))
# Out:
# 4
# <class 'int'>
# 4.8
# <class 'float'>
# (4+2j)
# <class 'complex'>

# %%
from traitlets import BaseDescriptor
#NUMBER OPERATION 
var_2
print(int(var_2))#convert float to int 
print(round(var_2))#nilai float dibulatkan 

A=1
B=2
C=A+B
D=A-B
E=A*B
F=A/B
G=30%4
H=40//6

print("Nilai C = ",C, "kilogram")
print(D)
print(E)
print(F)
print(G)
print(H, A, B, C)
print("Nilai", A, "+ Nilai", B,  " = Nilai", C)
# Out:
# 4
# 5
# Nilai C =  3 kilogram
# -1
# 2
# 0.5
# 2
# 6 1 2 3
# Nilai 1 + Nilai 2  = Nilai 3

# %%
#PERUBAHAN NILAI 
#jika ada perubahan nilai var, bikin step yg bagus lalu run all agar nilai sesuaai update-an 
#perhatikan 3 code kebawah 
#3 code kebawah adalah langkah yg baik semisal nanti ada perubahan nilai dg ngerun all 

A=1
B=3

print(A)
print(B)
# Out:
# 1
# 3

# %%
C=A+B
print(C)
# Out:
# 4

# %%
print(C)
# Out:
# 4

# %%
import string
#STRING 

var_string1="Hello"
var_string2="World"
var_string3=var_string1 + " " + var_string2


print(var_string1) 
print(var_string2)

print(var_string1, var_string2)#tanpa \n (satu line )
print(var_string3)
# Out:
# Hello
# World
# Hello World
# Hello World

# %%
#STRING MANIPULATION 
var_search="o"
print("jumlah karakter: ", len(var_string3))#(ingin melihat panjangnya suatu var )

print("count karakter",var_search, ":", var_string3.count(var_search)) #(melihat banyaknya suatu karakter

print("Replace world with another word: ", var_string3.replace("World", "you"))#mengganti kata sebelumnya dengan kata yang baru 

print("spliting by space: ", var_string3.split(" "))

print("Upper: ", var_string3.upper())#ubah semua jd kapital

print("Lower: ", var_string3.lower())#ubah semua huruf jadi kecil

#ingin mengambil beberapa karakter dari string pada variabel 
var_string3[0]#ambil karakter pertama dari kalimat hello world

var_string3[len(var_string3)-1]#ambil huruf paling belakang

var_string3[-2]#ambil karakter ke-2 dari belakang dengan cara simple 

print("ambil beberapa karakter di urutan tertentu: ", var_string3[0:3])#ambil 3 huruf pertama(0-2), penulisan angka dibelakang hrs+1 jadi [0:(2+1)]
# Out:
# jumlah karakter:  11
# count karakter o : 2
# Replace world with another word:  Hello you
# spliting by space:  ['Hello', 'World']
# Upper:  HELLO WORLD
# Lower:  hello world
# ambil beberapa karakter di urutan tertentu:  Hel

# %%
## TEST CASE ##

#quiz 1

plat1 = "B123XX" #kode daerah B, kode angka 123, kode huruf XX
plat2 = "AB56AA"
plat3 = "D1234567CC"
plat4 = "ABCD1234EFGHI"
#menentukan kode daerah, kode huruf pada masing masing plat 
plat_to_check = plat1

plat_to_check = plat_to_check.replace["1", "0"]
plat_to_check = plat_to_check.replace["2", "0"]
plat_to_check = plat_to_check.replace["3", "0"]
plat_to_check = plat_to_check.replace["4", "0"]
plat_to_check = plat_to_check.replace["5", "0"]
plat_to_check = plat_to_check.replace["6", "0"]
plat_to_check = plat_to_check.replace["7", "0"]
plat_to_check = plat_to_check.replace["8", "0"]
plat_to_check = plat_to_check.replace["9", "0"]


print(plat_To_check)
print("kode daerah: ", plat_To_check.split("0")[0])
print("kode huruf: ", plat_To_check.split("0")[-1])



#output: kode daerah: kode huruf:
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-70a58289a95b> in <module>
#      10 plat_to_check = plat1
#      11
# ---> 12 plat_to_check = plat_to_check.replace["1", "0"]
#      13 plat_to_check = plat_to_check.replace["2", "0"]
#      14 plat_to_check = plat_to_check.replace["3", "0"]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
#LIST

list_1 = [1,2,3,4,5]
list_2 = ["apple", "banana"]
list_3 = [1,2,3,"apple", "banana"]
list_4 = [[1,2,3], ["ayam", "bebek"]]
list_5 = [list_1, list_2, list_3]

print(list_1)
print(list_2)
print(list_3)
print(list_4)
print(list_5)
# Out:
# [1, 2, 3, 4, 5]
# ['apple', 'banana']
# [1, 2, 3, 'apple', 'banana']
# [[1, 2, 3], ['ayam', 'bebek']]
# [[1, 2, 3, 4, 5], ['apple', 'banana'], [1, 2, 3, 'apple', 'banana']]

# %%
#LIST MANIPULATIION 
list_6 = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j"]

print(list_6)
print(len(list_6))#panjang list 
print(list_6[0])#karakter awal
print(list_6[-1])#karakter akhir 
print(list_6[1:4])#ingin mengambil 3 karakter dari urutan kedua(b) 

n=len(list_6)
print(list_6[n-3:n]) #ekuivalen dg print(list_6[-3::])
print(list_6[-3::])
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# 10
# a
# j
# ['b', 'c', 'd']
# ['h', 'i', 'j']
# ['h', 'i', 'j']

# %%
#list manipulation 2

list_a = ["ayam", "bebek"]
list_b = ["gajah", "kuda"]
list_c= list_a + list_b #ingin menggabungkan kedua list 

print(list_a)
print(list_b)
print(list_c)#kedua list a dan b sudah bergabung 
list_c.remove("kuda")
#menambahkan list_c.append("domba")
print(list_c)

list_d= list_c[0:2] + ["kucing"] + list_c[-1::]
print(list_d)
# Out:
# ['ayam', 'bebek']
# ['gajah', 'kuda']
# ['ayam', 'bebek', 'gajah', 'kuda']
# ['ayam', 'bebek', 'gajah']
# ['ayam', 'bebek', 'kucing', 'gajah']

# %%
#SET

set_1 = {1,2,3}
set_2 = {"a", "b", "c"}

print(set_1)
print(set_2)
# Out:
# {1, 2, 3}
# {'a', 'b', 'c'}

# %%
#TUPPLE

tupple_1={1,2,3}
tupple_2={"a", "b", "c"}

# %%
#DICTIONARY 

dict_1={"var 1":"value 1", "var 2": "value_2" }
biodata_fulan{"nama": "fulan", "gender": "pria", "kebangsaan": "indonesia"}

print(dict_1)
print(biodata_fulan)
print(biodata_fulan["nama"])
print(biodata_fulan["gender"])

biodata
# Out:
#   File "<ipython-input-39-0c811e9d6b5a>", line 4
#     biodata_fulan{"nama": "fulan", "gender": "pria", "kebangsaan": "indonesia"}
#                  ^
# SyntaxError: invalid syntax

# %%
#BOOLEAN 

bool_A = True
bool_B = False 

print("argumen A: ", bool_A)
print("argumen B: ", bool_B)

#menginverse argumen 
print("inverse argument A: ", not(bool_A))

#operasi 
D=2+3 ==4+1
print(D)

#and  or?
C= True and True 
D= True and False 
E= False and True 
F= False and False 
print(C,D,E,F)
# Out:
# argumen A:  True
# argumen B:  False
# inverse argument A:  False
# True
# True False False False

# %%
#CONDITION 

#jika ada telur segar maka kita beli 2 kg telur 
#jika tidak, maka beli 1 kg telur 

#kodisi= telur segar 
#action 1= beli 2kg telur 
#action 2= beli 1kg telur 

segar=True 
beli = 0

if segar: 
 beli = 2
else: 
  beli = 1 

print("beli telur", beli, "kg")
# Out:
# beli telur 2 kg

# %%
#condition lampu merah

#lampu merah = mobil berhenti 
#lampu kuning, mobil hati2
#lampu hijau, jalan 

lampu= input("Warna lampu: ")
mobil= "idle"

if lampu=="merah":
 mobil="berhenti"
elif lampu=="kuning:
mobil="hati-hati"
elif lampu=="hijau":
  mobil="jalan"
else: 
  mobi="ekstra hati-hati"
  print("kondisi mobil: ", mobil)
# Out:
#   File "<ipython-input-49-cba9c6d78224>", line 12
#     elif lampu=="kuning:
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
#FOR LOOP



for i in range(10): #ke print 10 kali 
  print("hello world") 
print ()

print("contoh lain")
for char in list_6[0:4]:
 print(char)
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
#
# contoh lain
# a
# b
# c
# d

# %%
#WHILE 
num=0 
while num<5:
  print(num)
  num+=1S
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#CONTOH WHILE 
jawaban=666
tebakan=0

while tebakan!= jawaban:
  tebakan= int(input("tebak angka 1-1000: "))

print("jawaban benar")
# Out:
# tebak angka 1-1000: 666
# jawaban benar

# %%
#FUNCTION 

def convert_CtoF(c): 
  f= c/5*9+32
  return(f)

c = int(input("suhu celcius: "))
print("konversi fahrenheit: ", convert_CtoF(c))
# Out:
# suhu celcius: 30
# konversi fahrenheit:  86.0
